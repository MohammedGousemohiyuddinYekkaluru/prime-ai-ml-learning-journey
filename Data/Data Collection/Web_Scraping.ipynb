# %%
# WEB SCRAPING

import requests

# %%
URL = "https://www.scrapethissite.com/pages/simple/"

res = requests.get(URL)

# %%
if res.status_code == 200:
    print(res.headers)
else:
    print("Failed to fetch the data")

with open("Scraped _data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Tue, 16 Dec 2025 08:09:16 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=SpPHV6Xvm9Srg7KOMJJZt7eYYbPQ6MOk6OSZkCs4Izc%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1765872555"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=SpPHV6Xvm9Srg7KOMJJZt7eYYbPQ6MOk6OSZkCs4Izc%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1765872555"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9aecb291fdfa6670-AMS', 'alt-svc': 'h3=":443"; ma=86400'}
